# %%
# The API that I will be using can be found here: https://github.com/swar/nba_api
# I am going along with the examples that can be found here https://github.com/swar/nba_api/blob/master/docs/examples/Basics.ipynb

# %%
import nba_api
from nba_api.stats.static import teams, players
from nba_api.stats.endpoints import playercareerstats, leaguegamefinder, playerdashboardbyclutch, playergamelogs
import pandas as pd

# %%
nba_teams = teams.find_teams_by_full_name("Portland Trail Blazers")[0]['id']
nba_teams
# Out:
# 1610612757

# %%
test = players.find_player_by_id(player_id='203081')
test

#nba_players = players.get_players()
#nba_players[:10] #Just printing the first 10 for space
# Out:
# {'id': 203081,
#  'full_name': 'Damian Lillard',
#  'first_name': 'Damian',
#  'last_name': 'Lillard',
#  'is_active': True}

# %%
#this should allow me to find Damian Lillard's unique player id,
Lillard = [player for player in nba_players if player['full_name'] == "Damian Lillard"]
Lillard
# Out:
# [{'id': 203081,
#   'full_name': 'Damian Lillard',
#   'first_name': 'Damian',
#   'last_name': 'Lillard',
#   'is_active': True}]

# %%
# Now I can find his stats
career = playercareerstats.PlayerCareerStats(player_id='203081')
career.get_data_frames()
# Out:
# [   PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
#  0     203081   2012-13        00  1610612757               POR        22.0
#  1     203081   2013-14        00  1610612757               POR        23.0
#  2     203081   2014-15        00  1610612757               POR        24.0
#  3     203081   2015-16        00  1610612757               POR        25.0
#  4     203081   2016-17        00  1610612757               POR        26.0
#  5     203081   2017-18        00  1610612757               POR        27.0
#  6     203081   2018-19        00  1610612757               POR        28.0
#  7     203081   2019-20        00  1610612757               POR        29.0
#  8     203081   2020-21        00  1610612757               POR        30.0
#
#     GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
#  0  82  82  3167.0  553  ...   0.844    42   215  257  531   74   19  243  172
# ...

# %%
#Isolating Free Throws Made per game

playerLogs = playergamelogs.PlayerGameLogs(player_id_nullable='203081').get_data_frames()[0]



#playerLogs.data="FTM"
playerLogs['FTM']
# Out:
# 0     14
# 1      7
# 2      4
# 3      8
# 4     13
# 5      7
# 6      1
# 7      4
# 8      2
# 9      8
# 10     3
# 11    12
# 12     6
# 13     9
# 14     9
# 15     9
# 16     3
# 17    12
# 18     4
# 19     3
# 20     8
# 21     5
# 22     4
# 23     5
# 24     6
# 25     6
# 26    10
# 27     0
# 28     7
# 29     4
#       ..
# 45    11
# 46     3
# 47    10
# 48     2
# 49     6
# 50     8
# 51     5
# 52     9
# 53     5
# 54     5
# 55     5
# 56    11
# 57     6
# 58     9
# 59     4
# 60     2
# 61     7
# 62     3
# 63     4
# 64    15
# 65     7
# 66     6
# 67    11
# 68    11
# 69    13
# 70     8
# 71    11
# 72     5
# 73     5
# 74     9
# Name: FTM, Length: 75, dtype: int64

# %%
type(playerLogs)
# Out:
# nba_api.stats.endpoints.playergamelogs.PlayerGameLogs

# %%
test = playergamelogs.PlayerGameLogs(player_id_nullable='203081')
test.get_data_frames()[0]
# Out:
#    SEASON_YEAR  PLAYER_ID     PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  \
# 0      2016-17     203081  Damian Lillard  1610612757               POR
# 1      2016-17     203081  Damian Lillard  1610612757               POR
# 2      2016-17     203081  Damian Lillard  1610612757               POR
# 3      2016-17     203081  Damian Lillard  1610612757               POR
# 4      2016-17     203081  Damian Lillard  1610612757               POR
# 5      2016-17     203081  Damian Lillard  1610612757               POR
# 6      2016-17     203081  Damian Lillard  1610612757               POR
# 7      2016-17     203081  Damian Lillard  1610612757               POR
# 8      2016-17     203081  Damian Lillard  1610612757               POR
# 9      2016-17     203081  Damian Lillard  1610612757               POR
# 10     2016-17     203081  Damian Lillard  1610612757               POR
# 11     2016-17     203081  Damian Lillard  1610612757               POR
# ...
